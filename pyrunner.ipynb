# %% [markdown]
# <a href="https://colab.research.google.com/github/guy-davidi/my_DeepDPM/blob/main/pyrunner.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Configure GitAPI
username= 'guy-davidi'
repo = 'my_DeepDPM'
branch = 'main'
token = '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'

# !git config --global user.name "guy-davidi"
# !git config --global user.email "guydav1111@gmail.com"
# !git config --global user.passord ""

#clone specific branch from git repository
# !git clone -b {branch} https://{token}@github.com/{username}/{repo}
# Out:
# Cloning into 'my_DeepDPM'...
# remote: Enumerating objects: 188, done.
# remote: Counting objects: 100% (188/188), done.
# remote: Compressing objects: 100% (134/134), done.
# remote: Total 188 (delta 53), reused 180 (delta 51), pack-reused 0
# Receiving objects: 100% (188/188), 146.10 MiB | 32.54 MiB/s, done.
# Resolving deltas: 100% (53/53), done.
# Checking out files: 100% (80/80), done.

# %%
# Install all requirements
# according to requirements  torch==1.11.0 ->torchtext==0.12.0 torchvision==0.12.0 torchaudio==0.12.0
# but the following versions work properly:
# !pip install  torch==1.9.0 torchtext==0.10.0 torchvision==0.10.0 torchaudio==0.9.0 

# !pip install joblib==1.1.0
# !pip install kmeans_pytorch==0.3
# !pip install matplotlib==3.5.1
# !pip install numpy==1.20.3 
# !pip install Pillow==9.0.1
# !pip install pytorch_lightning==1.2.10
# !pip install neptune-client==0.16.1
# !pip install scikit_learn==1.0.2
# !pip install scipy==1.7.3
# !pip install seaborn==0.11.2
# !pip install tqdm==4.63.0
# !pip install umap==0.1.1
# !pip install umap_learn==0.5.2
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 831.4 MB 2.8 kB/s
# ...
#      |████████████████████████████████| 7.6 MB 58.7 MB/s
# ...
#      |████████████████████████████████| 22.1 MB 103.4 MB/s
# ...
#      |████████████████████████████████| 1.9 MB 42.3 MB/s
# ...
#   Attempting uninstall: torch
#     Found existing installation: torch 1.12.1+cu113
#     Uninstalling torch-1.12.1+cu113:
#       Successfully uninstalled torch-1.12.1+cu113
#   Attempting uninstall: torchvision
#     Found existing installation: torchvision 0.13.1+cu113
#     Uninstalling torchvision-0.13.1+cu113:
#       Successfully uninstalled torchvision-0.13.1+cu113
#   Attempting uninstall: torchtext
#     Found existing installation: torchtext 0.13.1
#     Uninstalling torchtext-0.13.1:
#       Successfully uninstalled torchtext-0.13.1
#   Attempting uninstall: torchaudio
#     Found existing installation: torchaudio 0.12.1+cu113
# ...

# %%
#To generate a similar gif to the one presented above
# !python /content/my_DeepDPM/DeepDPM.py --dataset synthetic --log_emb every_n_epochs --log_emb_every 1

# %%
# !python DeepDPM.py --dataset stl10 --init_k 3 --dir pretrained_embeddings/MOCO/STL10 --NIW_prior_nu 514 --prior_sigma_scale 0.05 --gpus 0 --use_labels_for_eval
# Out:
# hi start training...
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 6 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Test data not found! running only with train data
# NeptuneLogger will work in online mode
# No Neptune API token defined!
# Please define Neptune API token or run with the --offline argument.
# Running without logging...
# Sequential()
# GPU available: True, used: True
# TPU available: False, using: 0 TPU cores
# /usr/local/lib/python3.7/dist-packages/pytorch_lightning/utilities/distributed.py:68: UserWarning: you defined a validation_step but have no val_dataloader. Skipping validation loop
# ...

# %%
#useful commands
# %cd /content/my_DeepDPM
# !pwd
# !git status
#!git add --all
#!git commit -m "runner with stl10"
#!git push
# Out:
# /content/my_DeepDPM
# /content/my_DeepDPM
# On branch main
# Your branch is ahead of 'origin/main' by 1 commit.
#   (use "git push" to publish your local commits)
#
# nothing to commit, working tree clean

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive
